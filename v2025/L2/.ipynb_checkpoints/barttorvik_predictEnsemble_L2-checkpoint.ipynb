# %%
#this ensemble will combine RF + NN

# %%
import joblib
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# ✅ Load Random Forest model
rf_model = joblib.load("rf_elite8_model.pkl")  # Change filename if needed

# ✅ Load Neural Network model
nn_model = load_model("elite8_nn_model.h5")

# ✅ Load the scaler (same one used for NN)
scaler = joblib.load("elite8_scaler.pkl")

# %%
# Load new dataset (change file if needed)
df_new = pd.read_csv("new_tournament_data.csv")

# Keep only the same important features
important_features = [
    "Barthag", "AdjOE", "Rk", "Seed", "EFG%", "FTRD", 
    "2P%", "AdjDE", "3P%", "DRB", "TORD", "ORB", 
    "3P%D", "2P%D", "TOR"
]
X_new = df_new[important_features]

# Normalize features using the saved scaler
X_new_scaled = scaler.transform(X_new)
